# %%
from style_transfer import StyleTransferModel
from config import config
from IPython.display import Image
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
model = StyleTransferModel(config)

# %% [markdown]
# #### Original Image:

# %%
Image(config['original_image_path'], width=config['image_size'], height=config['image_size'])

# %% [markdown]
# #### Style Image:

# %%
Image(config['style_image_path'], width=config['image_size'], height=config['image_size'])

# %% [markdown]
# #### Transformed Image:

# %%
model.do_style_transfer()
# Out:
# Current loss value: 20731.0136719
# Current loss value: 12580.5800781
# Current loss value: 8947.01171875
# Current loss value: 6653.16992188
# Current loss value: 5432.96972656
# Current loss value: 4879.36132812
# Current loss value: 4650.61132812
# Current loss value: 4485.32519531
# Current loss value: 4293.74169922
# Current loss value: 4128.00830078

# %%
Image('images/results/res_at_iteration_' + str(config['iterations']) + '.png', width=config['image_size'], height=config['image_size'])
